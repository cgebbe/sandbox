# %%
# Use docker image: jupyter/datascience-notebook

# %%
# !pip install geopandas

# %%
import geopandas as gpd

# %%
# !pip install joblib

# %%
import joblib

# %%
mem=joblib.memory.Memory(location="cache", backend="local", verbose=3, bytes_limit=100e6)

# %%
mem.store_backend.get_items()
# Out:
# [CacheItemInfo(path='cache/joblib/__main__--tmp-ipykernel-3529038902/get_gdf/6e5e283319c890d02c465b10d6f4b6e7', size=1547715, last_access=datetime.datetime(2023, 3, 4, 22, 56, 58, 541788)),
#  CacheItemInfo(path='cache/joblib/__main__--tmp-ipykernel-3529038902/get_gdf/4652c901c0c669e4db83383b50f91968', size=1547715, last_access=datetime.datetime(2023, 3, 4, 22, 8, 47, 26580))]

# %%
@mem.cache
def get_gdf(name: str):
    return gpd.read_file(gpd.datasets.get_path('nybb'))

# %%
def hello():
    return gpd.read_file(gpd.datasets.get_path('nybb'))

hello.__code__.co_name
# Out:
# 'hello'

# %%
get_gdf("foo")
# Out:
# [Memory]37.8s, 0.6min   : Loading get_gdf...
#    BoroCode       BoroName     Shape_Leng    Shape_Area  \
# 0         5  Staten Island  330470.010332  1.623820e+09
# 1         4         Queens  896344.047763  3.045213e+09
# 2         3       Brooklyn  741080.523166  1.937479e+09
# 3         1      Manhattan  359299.096471  6.364715e+08
# 4         2          Bronx  464392.991824  1.186925e+09
#
#                                             geometry
# 0  MULTIPOLYGON (((970217.022 145643.332, 970227....
# 1  MULTIPOLYGON (((1029606.077 156073.814, 102957...
# 2  MULTIPOLYGON (((1021176.479 151374.797, 102100...
# 3  MULTIPOLYGON (((981219.056 188655.316, 980940....
# 4  MULTIPOLYGON (((1012821.806 229228.265, 101278...

# %%
get_gdf("bar")

# %%
path="cache/joblib/__main__--tmp-ipykernel-3529038902/get_gdf/4652c901c0c669e4db83383b50f91968/output.pkl"
with open(path, "rb") as f:
    pickle.load(f)

# %%
mem.store_backend

# %%
mem.reduce_size()

# %%
items=mem.store_backend.get_items()
itemsj

# %%
p = Path(items[0].path) / "output.pkl"
p.exists()

# %%
x=type(items[0])
x

# %%
# %logstart

# %%
# !cat ipython_log.py

# %%
# %pastebin

# %%
print("youhu!")

# %%
with open(p,"rb") as f:
    pickle.load(f)

# %%
sum(i.size for i in items) / 1e6

# %%
item=items[0]
item

# %%
item??

# %%
# %whos

# %%
# %quickref

# %%
item?

# %%
xs=list(range(20))
dct={x:x for x in xs}
print(dct)

# %%
# %pinfo2 item

# %%
# %psource mem.store_backend
